# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
import numpy as np
import pandas as pd

# %%
lineal = pd.read_csv("C:/Users/luciana H/Desktop/YulietMira/UNIVERSIDAD/SEMESTRE 5/ANALISIS DE DATOS/Etapa 2/data.csv", sep=",")

# %%
lineal.columns
lineal.info
lineal.describe
# Out:
# <bound method NDFrame.describe of    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500>

# %%
lineal.hist()
# Out:
# array([[<Axes: title={'center': 'metro'}>,
#         <Axes: title={'center': 'precio'}>]], dtype=object)

# %%
lineal.plot.scatter(x="precio", y="metro")
plt.show()

# %%
reglinea = linear_model.LinearRegression()

# %%
linea = lineal["metro"].values.reshape((-1,1))

# %%
modelo = reglinea.fit(linea, lineal["metro"])

# %%
print("Interseccion (b)", modelo.intercept_)
print("Pendiente (m)", modelo.coef_)
# Out:
# Interseccion (b) 0.0
# Pendiente (m) [1.]

# %%
lineal.plot.scatter(x="metro", y="precio", label='Datos reales')
plt.scatter(entra, predecir, color='red')
plt.plot(entra, predecir, color='orange', label='Linea Regresión')
plt.xlabel('metro')
plt.ylabel('precio')
plt.legend()
plt.show()
